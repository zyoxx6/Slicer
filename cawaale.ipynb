# %% [markdown]
# <a href="https://colab.research.google.com/github/zyoxx6/Slicer/blob/main/cawaale.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GPT-SoVITS WebUI

# %% [markdown]
# ## Env Setup (Run Once Only)
# ## 环境配置, 只需运行一次

# %% [markdown]
# ### 1.

# %%
# %%writefile /content/setup.sh
# set -e
#
# cd /content
#
# git clone https://github.com/RVC-Boss/GPT-SoVITS.git
#
# cd GPT-SoVITS
#
# if conda env list | awk '{print $1}' | grep -Fxq "GPTSoVITS"; then
#     :
# else
#     conda create -n GPTSoVITS python=3.10 -y
# fi
#
# source activate GPTSoVITS
#
# pip install ipykernel
#
# bash install.sh --device CU126 --source HF --download-uvr5
# Out:
# Writing /content/setup.sh

# %% [markdown]
# ### 2.

# %%
# %pip install -q condacolab
import condacolab
condacolab.install_from_url("https://repo.anaconda.com/archive/Anaconda3-2024.10-1-Linux-x86_64.sh")
# !cd /content && bash setup.sh
# Out:
# ⏬ Downloading https://repo.anaconda.com/archive/Anaconda3-2024.10-1-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:01:53
# 🔁 Restarting kernel...
# Cloning into 'GPT-SoVITS'...
# remote: Enumerating objects: 5832, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 5832 (delta 15), reused 4 (delta 4), pack-reused 5803 (from 3)
# Receiving objects: 100% (5832/5832), 14.07 MiB | 14.51 MiB/s, done.
# Resolving deltas: 100% (3342/3342), done.
# Channels:
#  - defaults
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/GPTSoVITS
#
#   added / updated specs:
#     - python=3.10
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2025.12.2  |       h06a4308_0         125 KB
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 3. Restore Data from your "Vault"
# !cp /content/drive/MyDrive/Somali_Pro_Project/jelle_4k.zip /content/
# !unzip -q /content/jelle_4k.zip -d /content/jelle_audio
# !cp /content/drive/MyDrive/Somali_Pro_Project/somali_pro.list /content/
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)

# %% [markdown]
# ## Launch WebUI
# ## 启动 WebUI

# %%
# 1. Update the system's C++ library to the modern version
print("Updating system libraries...")
# !sudo add-apt-repository ppa:ubuntu-toolchain-r/test -y
# !sudo apt-get update
# !sudo apt-get install --only-upgrade libstdc++6 -y

# 2. Force the internal 'GPTSoVITS' environment to use the new C++ math logic
# This is crucial because the notebook uses a hidden Conda room
print("Fixing the internal Conda environment...")
# !/usr/local/bin/conda install -n GPTSoVITS -c conda-forge "libstdcxx-ng>=13" -y

# 3. Tell Python to look at the new library FIRST
import os
os.environ['LD_PRELOAD'] = '/usr/lib/x86_64-linux-gnu/libstdc++.so.6'

# 4. Final Verification
print("Verifying fix...")
# !strings /usr/lib/x86_64-linux-gnu/libstdc++.so.6 | grep CXXABI_1.3.15
# Out:
# Updating system libraries...
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# PPA publishes dbgsym, you may need to include 'main/debug' component
# Repository: 'deb https://ppa.launchpadcontent.net/ubuntu-toolchain-r/test/ubuntu/ jammy main'
# Description:
# Toolchain test builds; see https://wiki.ubuntu.com/ToolChain
#
# More info: https://launchpad.net/~ubuntu-toolchain-r/+archive/ubuntu/test
# Adding repository.
# Adding deb entry to /etc/apt/sources.list.d/ubuntu-toolchain-r-ubuntu-test-jammy.list
# Adding disabled deb-src entry to /etc/apt/sources.list.d/ubuntu-toolchain-r-ubuntu-test-jammy.list
# Adding key to /etc/apt/trusted.gpg.d/ubuntu-toolchain-r-ubuntu-test.gpg with fingerprint C8EC952E2A0E1FBDC5090F6A2C277A0A352154E5
# Get:1 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# ...

# %%
# !/usr/local/envs/GPTSoVITS/bin/python -m pip install --force-reinstall torchaudio --index-url https://download.pytorch.org/whl/cu126
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Looking in indexes: https://download.pytorch.org/whl/cu126
# ...
#   Using cached https://download.pytorch.org/whl/cu126/torch-2.10.0%2Bcu126-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (30 kB)
# ...
#   Using cached filelock-3.20.0-py3-none-any.whl.metadata (2.1 kB)
# ...
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# ...
#   Using cached https://download.pytorch.org/whl/jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached fsspec-2025.12.0-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached https://download.pytorch.org/whl/cu126/cuda_bindings-12.9.4-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (2.6 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 204.4 MB/s  0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.7/897.7 kB 357.0 MB/s  0:00:00
# ...

# %%
# !mv /content/jelle_audio/jelle_audio /content/jelle
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)

# %%
# !rm /usr/local/lib/libstdc++.so.6
# !ln -s /usr/local/envs/GPTSoVITS/lib/libstdc++.so.6 /usr/local/lib/libstdc++.so.6

# %%
# !cd /content/GPT-SoVITS && source activate GPTSoVITS && export is_share=True && python webui.py
# Out:
# Running on local URL:  http://0.0.0.0:9874
# Running on public URL: https://06a995333bbb5139fe.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# "/usr/local/envs/GPTSoVITS/bin/python" -s GPT_SoVITS/prepare_datasets/1-get-text.py
# "/usr/local/envs/GPTSoVITS/bin/python" -s GPT_SoVITS/prepare_datasets/1-get-text.py
# /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages/requests/__init__.py:113: RequestsDependencyWarning: urllib3 (2.6.3) or chardet (6.0.0.post1)/charset_normalizer (3.4.4) doesn't match a supported version!
#   warnings.warn(
# /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages/requests/__init__.py:113: RequestsDependencyWarning: urllib3 (2.6.3) or chardet (6.0.0.post1)/charset_normalizer (3.4.4) doesn't match a supported version!
#   warnings.warn(
# jelle_0000.wav
# jelle_0001.wav
# jelle_0002.wav
# jelle_0004.wav
# ...
